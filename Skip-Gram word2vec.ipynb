# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word:count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop  = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None,None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6628 0.3113 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6661 0.3051 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5102 0.3020 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6333 0.3279 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4951 0.3052 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5245 0.2989 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5497 0.2984 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5578 0.2967 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4725 0.2974 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4330 0.2981 sec/batch
# Nearest to will: griffon, corps, reverie, dishes, albret, madison, scummvm, amoral,
# Nearest to known: seabirds, seduce, disconcerting, resultant, placenta, rosenzweig, plinth, qing,
# Nearest to zero: ignite, somme, panjabi, trojans, formalization, nf, disliked, beaumont,
# Nearest to only: invent, enrollment, mentored, valve, princeto, physik, phd, mocking,
# Nearest to state: medium, sorenson, hu, croix, slashing, citizenship, hong, motherboard,
# Nearest to be: trumbo, blogs, eircom, vlachs, monotheist, flier, mycelium, harm,
# Nearest to about: quatrain, bauhin, umts, reflector, rework, funding, grained, aq,
# Nearest to may: complicated, nio, faust, iehovah, infective, klystron, corvettes, rightmost,
# Nearest to running: nero, mci, stimulating, goodrich, ribs, paseo, flotation, costumed,
# Nearest to versions: blot, shear, maupassant, livonian, tropical, princeton, insubordination, frivolity,
# Nearest to mathematics: belatedly, aquino, radiosity, lle, tara, rookies, risso, tierney,
# Nearest to bbc: essentialism, ramesses, jimmu, wartburg, orissa, pruning, aloft, loam,
# Nearest to consists: isonzo, novelization, reisman, goss, crush, myrtle, siddeley, yousef,
# Nearest to derived: cong, veterinarian, madam, abolitionism, iblis, trichomes, delight, everyday,
# Nearest to operating: photographic, mixture, dandelin, scoreless, sepals, homosexuals, nne, cpp,
# Nearest to heavy: clubhouse, pigmentation, slugged, keyes, impressed, watterson, dwindling, trek,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4832 0.3057 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4022 0.2986 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3303 0.2972 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2604 0.2971 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2214 0.2987 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2012 0.3003 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0867 0.2982 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0681 0.2973 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9854 0.2982 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9856 0.2982 sec/batch
# Nearest to will: corps, madison, griffon, class, dishes, impractical, write, cities,
# Nearest to known: seabirds, took, underneath, seduce, facilitates, help, widespread, artists,
# Nearest to zero: ignite, m, formalization, somme, trojans, panjabi, comparatively, disliked,
# Nearest to only: invent, enrollment, just, portion, forming, valve, physik, phd,
# Nearest to state: medium, hong, sorenson, eleven, united, hu, vanish, citizenship,
# Nearest to be: trumbo, acquisition, blogs, implies, harm, defining, fourier, kept,
# Nearest to about: quatrain, funding, bauhin, pay, linguists, transaction, grained, confused,
# Nearest to may: complicated, nio, mediterranean, corvettes, corner, eliade, layers, completion,
# Nearest to running: nero, costumed, sequestration, advantaged, stimulating, instances, goodrich, keaton,
# Nearest to versions: blot, maupassant, shear, mathematical, tropical, language, princeton, intersection,
# Nearest to mathematics: aquino, lle, belatedly, radiosity, eliminating, tara, rookies, mandate,
# Nearest to bbc: essentialism, ramesses, jimmu, orissa, wartburg, pruning, repairs, loam,
# Nearest to consists: novelization, crush, goss, reisman, isonzo, propagating, lexicon, result,
# Nearest to derived: everyday, taller, trichomes, prompted, examining, madam, secretary, canon,
# Nearest to operating: photographic, mixture, scoreless, jointly, going, homosexuals, sepals, mauna,
# Nearest to heavy: electrically, clubhouse, impressed, trek, watterson, keyes, apostle, dwindling,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9440 0.3017 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9207 0.2979 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9013 0.2983 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8753 0.2980 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8262 0.2965 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8466 0.2982 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8044 0.2981 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7849 0.2980 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7506 0.2984 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7706 0.2980 sec/batch
# Nearest to will: corps, dishes, griffon, madison, class, wanted, impractical, politically,
# Nearest to known: seabirds, seduce, resultant, underneath, surfaces, facilitates, widespread, artists,
# Nearest to zero: comparatively, formalization, ignite, m, trojans, disliked, panjabi, beaumont,
# Nearest to only: invent, enrollment, valve, forming, phd, portion, suppose, just,
# Nearest to state: medium, sorenson, united, vanish, hong, hu, eleven, citizenship,
# Nearest to be: implies, blogs, trumbo, harm, defining, vlachs, acquisition, fourier,
# Nearest to about: quatrain, funding, bauhin, transaction, umts, unpaved, rework, kirtland,
# Nearest to may: complicated, nio, advised, corvettes, faust, mediterranean, klystron, critique,
# Nearest to running: nero, costumed, stimulating, instances, sequestration, advantaged, const, ribs,
# Nearest to versions: blot, shear, maupassant, mathematical, language, tropical, transfer, frequency,
# Nearest to mathematics: aquino, belatedly, lle, eliminating, radiosity, tara, mandate, generalization,
# Nearest to bbc: essentialism, ramesses, jimmu, wartburg, orissa, repairs, pruning, loam,
# Nearest to consists: novelization, isonzo, goss, crush, gould, grinding, reisman, outsource,
# Nearest to derived: everyday, canon, taller, examining, prospects, modeled, prompted, ills,
# Nearest to operating: photographic, mixture, tramway, scoreless, homosexuals, methane, jointly, going,
# Nearest to heavy: electrically, dwindling, keyes, clubhouse, apostle, watterson, pigmentation, impressed,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8000 0.3028 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7609 0.2981 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7303 0.3007 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6891 0.2984 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7210 0.3001 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7341 0.2982 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7091 0.2995 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7235 0.2973 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6984 0.2982 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6396 0.2972 sec/batch
# Nearest to will: corps, madison, dishes, griffon, impractical, grief, truths, reverie,
# Nearest to known: seabirds, underneath, seduce, resultant, surfaces, facilitates, placenta, help,
# Nearest to zero: m, beaumont, formalization, comparatively, nationals, runways, trojans, ignite,
# Nearest to only: invent, valve, enrollment, pythons, forming, denoting, physik, mentored,
# Nearest to state: united, medium, sorenson, esa, hong, vanish, hu, murdock,
# Nearest to be: implies, blogs, harm, trumbo, fourier, defining, vlachs, monotheist,
# Nearest to about: quatrain, bauhin, unpaved, funding, umts, transaction, illustrious, kirtland,
# Nearest to may: complicated, advised, nio, faust, homophone, klystron, corvettes, mediterranean,
# Nearest to running: costumed, nero, stimulating, ribs, sequestration, intercity, const, instances,
# Nearest to versions: blot, shear, maupassant, mathematical, language, livonian, princeton, transfer,
# Nearest to mathematics: belatedly, aquino, lle, eliminating, loyalist, radiosity, tara, generalization,
# Nearest to bbc: essentialism, ramesses, jimmu, wartburg, pruning, loam, orissa, repairs,
# Nearest to consists: novelization, isonzo, goss, grinding, reisman, outsource, gould, propagating,
# Nearest to derived: everyday, trichomes, veterinarian, taller, prospects, weekends, ignorant, canon,
# Nearest to operating: tramway, benevolence, photographic, scoreless, mixture, methane, projectiles, mauna,
# Nearest to heavy: electrically, dwindling, keyes, clubhouse, pigmentation, apostle, slugged, fraternal,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6911 0.2997 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6632 0.2972 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6001 0.2989 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6362 0.2983 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6275 0.2980 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6657 0.2983 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6145 0.2113 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5666 0.2989 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5159 0.2983 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5019 0.2986 sec/batch
# Nearest to will: corps, dishes, griffon, impractical, madison, reverie, truths, grief,
# Nearest to known: seabirds, underneath, seduce, artists, disconcerting, placenta, surfaces, resultant,
# Nearest to zero: m, beaumont, runways, formalization, four, nationals, eight, comparatively,
# Nearest to only: invent, valve, pythons, enrollment, forming, physik, denoting, just,
# Nearest to state: united, medium, hong, esa, paterson, sorenson, vanish, murdock,
# Nearest to be: implies, blogs, harm, trumbo, case, defining, fourier, denote,
# Nearest to about: quatrain, bauhin, unpaved, rework, transaction, hexagon, umts, ux,
# Nearest to may: complicated, advised, klystron, nio, lucid, homophone, infective, preceding,
# Nearest to running: stimulating, ribs, costumed, sequestration, nero, mci, superman, canola,
# Nearest to versions: blot, shear, language, mathematical, maupassant, transfer, frequency, imaging,
# Nearest to mathematics: belatedly, aquino, lle, generalization, loyalist, eliminating, rookies, tara,
# Nearest to bbc: ramesses, essentialism, jimmu, wartburg, pruning, loam, algeciras, orissa,
# Nearest to consists: grinding, goss, novelization, isonzo, reisman, myrtle, outsource, babbling,
# Nearest to derived: everyday, trichomes, veterinarian, weekends, virial, prospects, exothermic, taller,
# Nearest to operating: tramway, interface, scoreless, benevolence, projectiles, photographic, switch, methane,
# Nearest to heavy: electrically, dwindling, clubhouse, slugged, pigmentation, fraternal, keyes, rohan,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4937 0.3009 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5197 0.2980 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4503 0.2986 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5126 0.2976 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5019 0.2978 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4788 0.2971 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4314 0.2972 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4036 0.2978 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4157 0.2983 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4024 0.2975 sec/batch
# Nearest to will: griffon, corps, impractical, dishes, madison, truths, grief, gluons,
# Nearest to known: seabirds, underneath, placenta, surfaces, artists, disconcerting, seduce, resultant,
# Nearest to zero: m, runways, formalization, purchasing, four, beaumont, nationals, eight,
# Nearest to only: pythons, valve, invent, suppose, just, enrollment, torque, mentored,
# Nearest to state: united, paterson, esa, hong, medium, vanish, states, ownership,
# Nearest to be: implies, blogs, case, harm, trumbo, functions, defining, long,
# Nearest to about: quatrain, bauhin, unpaved, moran, garifuna, hexagon, funding, transaction,
# Nearest to may: complicated, klystron, lucid, advised, problems, homophone, infective, alludes,
# Nearest to running: ribs, stimulating, costumed, mci, canola, sequestration, congestion, superman,
# Nearest to versions: blot, programmers, shear, language, frequency, maupassant, transfer, mathematical,
# Nearest to mathematics: aquino, belatedly, lle, generalization, socialize, loyalist, flatwater, ginette,
# Nearest to bbc: ramesses, essentialism, jimmu, pruning, wartburg, loam, songs, algeciras,
# Nearest to consists: grinding, goss, isonzo, reisman, wali, myrtle, propagating, novelization,
# Nearest to derived: everyday, virial, phonetic, veterinarian, exothermic, trichomes, examining, retribution,
# Nearest to operating: interface, switch, tramway, benevolence, projectiles, scoreless, photographic, methane,
# Nearest to heavy: electrically, pigmentation, clubhouse, dwindling, slugged, rohan, keyes, frozen,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4560 0.3008 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3957 0.2982 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4260 0.2973 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3711 0.2971 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4268 0.2979 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4244 0.2978 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3450 0.2989 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3655 0.2975 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4192 0.2978 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3537 0.2980 sec/batch
# Nearest to will: corps, impractical, griffon, truths, gluons, dishes, amoral, sum,
# Nearest to known: underneath, seabirds, artists, surfaces, disconcerting, resultant, rosenzweig, stoics,
# Nearest to zero: m, eight, formalization, four, seven, runways, beaumont, purchasing,
# Nearest to only: pythons, valve, invent, just, torque, denoting, suppose, mentored,
# Nearest to state: united, states, vanish, medium, citizenship, esa, lancaster, provisions,
# Nearest to be: implies, case, blogs, defining, harm, trumbo, fourier, monotheist,
# Nearest to about: bauhin, quatrain, moran, fact, unpaved, umts, funding, hexagon,
# Nearest to may: complicated, lucid, infective, klystron, advised, homophone, alludes, seekers,
# Nearest to running: ribs, costumed, tcl, totalling, stimulating, ippolito, sequestration, canola,
# Nearest to versions: blot, programmers, shear, frequency, interpreter, transfer, imaging, language,
# Nearest to mathematics: aquino, belatedly, generalization, lle, socialize, flatwater, k, loyalist,
# Nearest to bbc: ramesses, essentialism, jimmu, wartburg, emmy, loam, pruning, orson,
# Nearest to consists: grinding, goss, isonzo, myrtle, wali, probed, reisman, outsource,
# Nearest to derived: everyday, phonetic, exothermic, virial, posteriori, examining, root, accents,
# Nearest to operating: interface, switch, tramway, benevolence, interchange, working, magnification, projectiles,
# Nearest to heavy: electrically, dwindling, pigmentation, clubhouse, slugged, stabbing, rohan, frozen,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3951 0.3004 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3982 0.2978 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3585 0.2976 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3475 0.2981 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3837 0.2976 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3338 0.2974 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3736 0.2978 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4190 0.2974 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3076 0.2985 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3158 0.2963 sec/batch
# Nearest to will: impractical, corps, griffon, madison, gluons, truths, sustain, tarquinius,
# Nearest to known: seabirds, underneath, rosenzweig, disconcerting, stoics, artists, surfaces, resultant,
# Nearest to zero: m, six, seven, eight, four, purchasing, one, three,
# Nearest to only: pythons, invent, valve, torque, just, denoting, developer, simple,
# Nearest to state: united, states, citizenship, lancaster, rehabilitation, vanish, appointed, concerned,
# Nearest to be: implies, harm, case, trumbo, blogs, vlachs, fourier, defining,
# Nearest to about: bauhin, quatrain, moran, fact, ux, unpaved, rework, umts,
# Nearest to may: complicated, advised, seekers, lucid, homophone, infective, klystron, regarding,
# Nearest to running: costumed, ribs, tcl, totalling, congestion, ippolito, mci, stimulating,
# Nearest to versions: programmers, blot, interpreter, frequency, imaging, compatibles, gui, language,
# Nearest to mathematics: aquino, belatedly, generalization, lle, socialize, flatwater, k, generalizes,
# Nearest to bbc: ramesses, essentialism, jimmu, emmy, wartburg, orson, goran, mcintyre,
# Nearest to consists: goss, isonzo, grinding, wali, probed, myrtle, outsource, propagating,
# Nearest to derived: phonetic, everyday, exothermic, examining, virial, posteriori, root, accents,
# Nearest to operating: interface, switch, tramway, interchange, download, jointly, benevolence, scoreless,
# Nearest to heavy: electrically, pigmentation, dwindling, clubhouse, slugged, stabbing, frozen, rohan,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3296 0.3019 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2915 0.3003 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3468 0.2987 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3768 0.3004 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3874 0.2975 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2582 0.2976 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3186 0.2962 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3376 0.2976 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2003 0.2984 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2853 0.2982 sec/batch
# Nearest to will: impractical, griffon, gluons, truths, corps, sustain, wanted, sum,
# Nearest to known: rosenzweig, disconcerting, seabirds, artists, polynesia, underneath, satsuki, stoics,
# Nearest to zero: eight, six, one, m, seven, four, two, three,
# Nearest to only: pythons, valve, invent, just, conflate, torque, eis, webmail,
# Nearest to state: united, states, vanish, lancaster, center, partisans, medium, citizenship,
# Nearest to be: implies, case, harm, blogs, trumbo, fourier, intertwined, vlachs,
# Nearest to about: bauhin, moran, quatrain, garifuna, fact, unpaved, rework, umts,
# Nearest to may: complicated, lucid, infective, advised, homophone, seekers, klystron, fertilization,
# Nearest to running: ippolito, tcl, costumed, intercity, congestion, mci, totalling, stimulating,
# Nearest to versions: programmers, blot, gui, compatibles, frequency, interpreter, ritchie, wirth,
# Nearest to mathematics: aquino, generalization, belatedly, socialize, lle, flatwater, generalizes, timaeus,
# Nearest to bbc: essentialism, ramesses, jimmu, emmy, wartburg, orson, goran, diod,
# Nearest to consists: goss, wali, probed, grinding, myrtle, outsource, isonzo, dera,
# Nearest to derived: phonetic, everyday, posteriori, exothermic, root, virial, examining, accents,
# Nearest to operating: interface, switch, download, interchange, jointly, tramway, photographic, scoreless,
# Nearest to heavy: electrically, pigmentation, dwindling, slugged, clubhouse, stabbing, frozen, fires,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3158 0.3012 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2872 0.2973 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3198 0.1261 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2594 0.2986 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2151 0.2984 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2315 0.2990 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2296 0.2977 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2015 0.2980 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1967 0.2989 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1776 0.2976 sec/batch
# Nearest to will: impractical, griffon, corps, gluons, wanted, sustain, madison, truths,
# Nearest to known: artists, disconcerting, rosenzweig, underneath, seabirds, surfaces, heraclea, polynesia,
# Nearest to zero: six, eight, one, m, four, two, seven, three,
# Nearest to only: pythons, invent, just, valve, conflate, michiel, suppose, eis,
# Nearest to state: united, states, vanish, lancaster, partisans, overseas, medium, anglophones,
# Nearest to be: implies, harm, case, trumbo, intertwined, vlachs, vagueness, directionally,
# Nearest to about: bauhin, quatrain, moran, garifuna, fact, unpaved, kirtland, rework,
# Nearest to may: complicated, lucid, infective, memetic, advised, syndrome, iehovah, klystron,
# Nearest to running: ippolito, congestion, mci, costumed, tcl, intercity, totalling, stimulating,
# Nearest to versions: programmers, compatibles, gui, blot, interpreter, ritchie, frequency, shear,
# Nearest to mathematics: aquino, belatedly, generalization, socialize, lle, flatwater, generalizes, timaeus,
# Nearest to bbc: essentialism, jimmu, ramesses, emmy, goran, orson, wartburg, melzi,
# Nearest to consists: wali, goss, dera, grinding, myrtle, isonzo, probed, outsource,
# Nearest to derived: phonetic, everyday, arabic, root, phonemes, ancestors, greek, virial,
# Nearest to operating: interface, switch, interchange, download, ide, jointly, scoreless, photographic,
# Nearest to heavy: electrically, dwindling, pigmentation, slugged, clubhouse, stabbing, frozen, fires,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2311 0.3014 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2155 0.2968 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2239 0.2982 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1390 0.2981 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1814 0.3003 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1561 0.2982 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1682 0.2958 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1849 0.2975 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2063 0.2985 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1760 0.2982 sec/batch
# Nearest to will: impractical, gluons, griffon, sustain, wanted, truths, superclasses, tarquinius,
# Nearest to known: rosenzweig, stoics, surfaces, disconcerting, artists, underneath, comerica, polynesia,
# Nearest to zero: six, eight, one, seven, four, two, three, m,
# Nearest to only: pythons, invent, conflate, eis, michiel, just, suppose, valve,
# Nearest to state: united, states, vanish, lancaster, css, concerned, center, overseas,
# Nearest to be: implies, case, directionally, harm, intertwined, trumbo, vagueness, monotheist,
# Nearest to about: bauhin, quatrain, fact, moran, garifuna, rework, guardian, umts,
# Nearest to may: complicated, lucid, infective, fertilization, klystron, homophone, syndrome, memetic,
# Nearest to running: ippolito, tcl, congestion, mci, intercity, costumed, shuttlecock, totalling,
# Nearest to versions: programmers, compatibles, interpreter, gui, blot, frequency, ritchie, wirth,
# Nearest to mathematics: aquino, generalization, belatedly, socialize, lle, flatwater, generalizes, timaeus,
# Nearest to bbc: essentialism, jimmu, orson, emmy, ramesses, stations, melzi, goran,
# Nearest to consists: wali, dera, goss, outsource, myrtle, grinding, probed, isonzo,
# Nearest to derived: phonetic, everyday, root, virial, arabic, abolitionism, greek, continents,
# Nearest to operating: interface, switch, jointly, going, formatted, tramway, interchange, download,
# Nearest to heavy: electrically, dwindling, pigmentation, slugged, frozen, stabbing, minimi, tribesmen,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1718 0.3011 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2244 0.2977 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1482 0.2982 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1603 0.2976 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1736 0.2970 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1944 0.2978 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1835 0.2989 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1552 0.2967 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1409 0.2983 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2010 0.2989 sec/batch
# Nearest to will: impractical, gluons, sustain, wanted, emitter, griffon, bidi, superclasses,
# Nearest to known: rosenzweig, surfaces, axioms, stoics, disconcerting, artists, underneath, mauricien,
# Nearest to zero: six, two, eight, one, seven, three, four, five,
# Nearest to only: pythons, invent, michiel, just, developer, conflate, denoting, eis,
# Nearest to state: united, states, vanish, lancaster, concerned, center, danville, css,
# Nearest to be: implies, case, monotheist, directionally, vlachs, vagueness, trumbo, intertwined,
# Nearest to about: bauhin, quatrain, fact, moran, rework, garifuna, umts, guardian,
# Nearest to may: complicated, lucid, infective, jurassic, iehovah, klystron, seekers, memetic,
# Nearest to running: ippolito, tcl, mci, congestion, intercity, costumed, stimulating, shuttlecock,
# Nearest to versions: programmers, compatibles, interpreter, wirth, gui, ritchie, frequency, blot,
# Nearest to mathematics: aquino, generalization, belatedly, socialize, lle, generalizes, flatwater, timaeus,
# Nearest to bbc: jimmu, essentialism, orson, ramesses, goran, emmy, melzi, subs,
# Nearest to consists: dera, wali, myrtle, probed, goss, tagalog, outsource, isonzo,
# Nearest to derived: everyday, phonetic, virial, accents, root, greek, verbs, posteriori,
# Nearest to operating: interface, switch, interchange, download, formatted, ide, autocode, jointly,
# Nearest to heavy: electrically, dwindling, pigmentation, slugged, stabbing, tribesmen, fires, clubhouse,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2076 0.3017 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1672 0.2990 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1975 0.2975 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2114 0.2981 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1512 0.2990 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1385 0.2970 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1622 0.2981 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1240 36.2575 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1324 0.3313 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2194 36.2789 sec/batch
# Nearest to will: wanted, griffon, impractical, corps, sustain, madison, trieste, gluons,
# Nearest to known: polynesia, rosenzweig, artists, axioms, stoics, heraclea, surfaces, inaccurately,
# Nearest to zero: eight, six, one, two, seven, four, five, three,
# Nearest to only: pythons, michiel, invent, just, garrett, conflate, denoting, eis,
# Nearest to state: united, states, lancaster, vanish, concerned, citizenship, subspace, center,
# Nearest to be: case, implies, monotheist, vlachs, venera, trumbo, harm, vagueness,
# Nearest to about: bauhin, quatrain, moran, fact, garifuna, guardian, sinha, rework,
# Nearest to may: complicated, lucid, iehovah, peerages, seekers, infective, unexplainable, donuts,
# Nearest to running: ippolito, congestion, costumed, intercity, mci, tcl, shuttlecock, totalling,
# Nearest to versions: programmers, compatibles, gui, interpreter, ritchie, wirth, frequency, scripts,
# Nearest to mathematics: aquino, generalization, belatedly, lle, socialize, timaeus, flatwater, ginette,
# Nearest to bbc: jimmu, essentialism, goran, orson, links, landen, subs, ramesses,
# Nearest to consists: dera, probed, goss, myrtle, tagalog, wali, kerry, outsource,
# Nearest to derived: phonetic, everyday, virial, verbs, root, greek, suffixes, phonemes,
# Nearest to operating: interface, jointly, switch, download, ide, tramway, powerbook, interchange,
# Nearest to heavy: electrically, dwindling, slugged, pigmentation, stabbing, clubhouse, minimi, tribesmen,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2452 36.2801 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1217 0.3194 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1351 36.2755 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1476 0.3160 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0425 36.2749 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1556 0.3188 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1535 36.2892 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1642 36.2775 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1825 0.0410 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1303 36.2710 sec/batch
# Nearest to will: wanted, impractical, gluons, scrumpy, maintainer, sustain, griffon, corps,
# Nearest to known: artists, polynesia, axioms, surfaces, monocotyledons, comerica, rosenzweig, disconcerting,
# Nearest to zero: six, two, one, eight, seven, three, five, four,
# Nearest to only: pythons, michiel, just, torque, eis, chaerea, denoting, invent,
# Nearest to state: united, states, vanish, lancaster, medium, center, subspace, citizenship,
# Nearest to be: case, implies, vagueness, stocking, directionally, biases, venera, harm,
# Nearest to about: bauhin, fact, quatrain, garifuna, rework, moran, umts, external,
# Nearest to may: complicated, lucid, infective, iehovah, klystron, memetic, fertilization, jurassic,
# Nearest to running: ippolito, congestion, costumed, mci, tcl, shuttlecock, intercity, canola,
# Nearest to versions: programmers, compatibles, gui, interpreter, wirth, ritchie, macintosh, bitmapped,
# Nearest to mathematics: aquino, generalization, socialize, belatedly, flatwater, lle, logic, generalizes,
# Nearest to bbc: jimmu, essentialism, links, subs, orson, melzi, landen, goran,
# Nearest to consists: dera, tagalog, myrtle, goss, wali, probed, savanna, kerry,
# Nearest to derived: everyday, phonetic, virial, root, suffixes, veterinarian, verbs, greek,
# Nearest to operating: interface, ide, powerbook, autocode, jointly, download, going, scoreless,
# Nearest to heavy: electrically, dwindling, slugged, minimi, pigmentation, stabbing, tribesmen, clubhouse,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1045 0.3251 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0416 36.2904 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0893 0.3247 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0486 36.2853 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0721 36.2761 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0204 0.3168 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0900 36.2762 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1167 0.3160 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0961 36.2825 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0198 36.2749 sec/batch
# Nearest to will: wanted, gluons, corps, griffon, impractical, scrumpy, grumpy, bidi,
# Nearest to known: artists, axioms, rosenzweig, surfaces, polynesia, stoics, grenville, disconcerting,
# Nearest to zero: six, two, one, eight, seven, three, five, four,
# Nearest to only: pythons, eis, michiel, chaerea, just, conflate, torque, again,
# Nearest to state: united, states, vanish, medium, lancaster, css, subspace, citizenship,
# Nearest to be: case, implies, stocking, directionally, venera, vagueness, monotheist, absorbance,
# Nearest to about: bauhin, garifuna, fact, quatrain, moran, external, aconcagua, rework,
# Nearest to may: complicated, lucid, infective, memetic, klystron, fertilization, either, iehovah,
# Nearest to running: ippolito, congestion, mci, costumed, tcl, shuttlecock, canola, intercity,
# Nearest to versions: programmers, compatibles, gui, wirth, bitmapped, interpreter, ritchie, howling,
# Nearest to mathematics: aquino, generalization, belatedly, socialize, flatwater, lle, timaeus, algebraic,
# Nearest to bbc: links, essentialism, jimmu, subs, melzi, website, goran, personalized,
# Nearest to consists: dera, tagalog, myrtle, wali, probed, savanna, isonzo, goss,
# Nearest to derived: everyday, phonetic, virial, veterinarian, greek, suffixes, verbs, iehouah,
# Nearest to operating: interface, powerbook, autocode, ide, going, jointly, tramway, scoreless,
# Nearest to heavy: electrically, dwindling, slugged, minimi, pigmentation, tribesmen, flared, stabbing,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0309 0.3227 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0014 36.2848 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0314 0.3424 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0511 0.3168 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0647 36.2806 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0755 0.3254 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0348 36.2755 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1095 0.3195 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0463 8.6756 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0266 0.3120 sec/batch
# Nearest to will: wanted, gluons, impractical, emitter, natively, bidi, sum, maintainer,
# Nearest to known: artists, axioms, surfaces, stoics, monocotyledons, mauricien, rosenzweig, grenville,
# Nearest to zero: two, six, eight, one, seven, three, five, four,
# Nearest to only: pythons, this, just, denoting, michiel, conflate, eis, nda,
# Nearest to state: united, states, lancaster, vanish, medium, subspace, css, center,
# Nearest to be: case, implies, directionally, stocking, vagueness, venera, biases, absorbance,
# Nearest to about: bauhin, external, rework, fact, quatrain, garifuna, umts, moran,
# Nearest to may: complicated, lucid, infective, klystron, memetic, iehovah, fertilization, to,
# Nearest to running: ippolito, congestion, mci, intercity, costumed, tcl, bahr, shuttlecock,
# Nearest to versions: programmers, compatibles, gui, wirth, bitmapped, interpreter, ritchie, howling,
# Nearest to mathematics: aquino, generalization, belatedly, generalizes, flatwater, algebraic, socialize, logic,
# Nearest to bbc: links, jimmu, essentialism, subs, personalized, observances, melzi, emmy,
# Nearest to consists: dera, tagalog, wali, myrtle, probed, goss, isonzo, savanna,
# Nearest to derived: virial, everyday, posteriori, veterinarian, phonetic, iehouah, greek, suffixes,
# Nearest to operating: interface, powerbook, ide, autocode, going, formatted, tramway, jointly,
# Nearest to heavy: electrically, slugged, dwindling, minimi, pigmentation, tribesmen, stabbing, flared,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0826 0.3120 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0791 0.3019 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0480 0.2984 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0797 0.2975 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0596 0.2988 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0208 0.2988 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0567 0.2983 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0558 0.3021 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0964 0.2988 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0628 0.2990 sec/batch
# Nearest to will: wanted, natively, tarquinius, impractical, gluons, emitter, opted, corps,
# Nearest to known: artists, axioms, rosenzweig, monocotyledons, surfaces, stoics, inaccurately, grenville,
# Nearest to zero: two, six, one, eight, five, seven, four, three,
# Nearest to only: pythons, michiel, nda, denoting, chaerea, just, eis, nlds,
# Nearest to state: united, lancaster, danville, states, medium, vanish, subspace, citizenship,
# Nearest to be: case, implies, directionally, stocking, vlachs, venera, vagueness, biases,
# Nearest to about: bauhin, fact, quatrain, rework, external, uranus, guardian, garifuna,
# Nearest to may: lucid, complicated, infective, alaskan, peerages, iehovah, memetic, either,
# Nearest to running: congestion, ippolito, intercity, costumed, mci, bahr, shuttlecock, tcl,
# Nearest to versions: programmers, compatibles, gui, wirth, interpreter, ritchie, bitmapped, howling,
# Nearest to mathematics: aquino, belatedly, generalization, flatwater, lle, timaeus, socialize, logic,
# Nearest to bbc: links, jimmu, essentialism, subs, observances, personalized, emmy, goran,
# Nearest to consists: dera, myrtle, wali, tagalog, probed, savanna, goss, isonzo,
# Nearest to derived: virial, everyday, veterinarian, suffixes, phonetic, verbs, greek, iehouah,
# Nearest to operating: interface, powerbook, ide, autocode, going, scoreless, tramway, formatted,
# Nearest to heavy: electrically, slugged, dwindling, minimi, pigmentation, stabbing, lollapalooza, coolness,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0502 0.3017 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0071 0.2977 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0254 0.2962 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0722 0.3057 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0545 0.3190 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1214 0.3019 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1436 0.2978 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0335 0.2985 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0190 0.3000 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0476 0.2968 sec/batch
# Nearest to will: wanted, emitter, natively, impractical, bidi, sum, maintainer, ahead,
# Nearest to known: axioms, artists, monocotyledons, stoics, examine, polynesia, stale, inaccurately,
# Nearest to zero: two, six, one, eight, five, four, three, seven,
# Nearest to only: pythons, michiel, chaerea, this, nda, again, eis, haiti,
# Nearest to state: united, lancaster, states, medium, vanish, subspace, citizenship, danville,
# Nearest to be: case, implies, directionally, vagueness, biases, vlachs, venera, stocking,
# Nearest to about: external, bauhin, fact, guardian, rework, garifuna, quatrain, sinha,
# Nearest to may: lucid, complicated, alaskan, either, iehovah, memetic, to, peerages,
# Nearest to running: congestion, ippolito, intercity, costumed, tcl, mci, shuttlecock, bahr,
# Nearest to versions: programmers, compatibles, gui, wirth, interpreter, ritchie, bitmapped, scripts,
# Nearest to mathematics: aquino, belatedly, generalization, timaeus, lle, flatwater, foundations, avar,
# Nearest to bbc: links, jimmu, observances, essentialism, subs, personalized, goran, landen,
# Nearest to consists: dera, myrtle, tagalog, probed, wali, savanna, goss, appoints,
# Nearest to derived: everyday, virial, iehouah, veterinarian, suffixes, greek, verbs, trichomes,
# Nearest to operating: interface, autocode, ide, powerbook, tramway, going, scoreless, intellimouse,
# Nearest to heavy: electrically, dwindling, slugged, minimi, pigmentation, tribesmen, propellants, coolness,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9757 0.3008 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0189 0.2978 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0348 0.2990 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0071 0.2974 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0944 0.2980 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0334 0.2507 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0092 0.2990 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0039 0.2994 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0470 0.2984 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9591 0.2973 sec/batch
# Nearest to will: wanted, emitter, natively, opted, impractical, ahead, bite, bidi,
# Nearest to known: monocotyledons, grenville, artists, polynesia, stale, axioms, mauricien, inaccurately,
# Nearest to zero: two, one, six, eight, five, three, four, seven,
# Nearest to only: pythons, michiel, this, again, chaerea, nda, torque, nlds,
# Nearest to state: united, lancaster, states, danville, wisconsin, montana, vanish, subspace,
# Nearest to be: case, implies, venera, directionally, stocking, vagueness, biases, hopping,
# Nearest to about: external, bauhin, quatrain, uranus, fact, rework, garifuna, guardian,
# Nearest to may: lucid, memetic, alaskan, infective, iehovah, complicated, either, fertilization,
# Nearest to running: congestion, mci, tcl, ippolito, intercity, shuttlecock, costumed, bahr,
# Nearest to versions: programmers, compatibles, gui, wirth, interpreter, bitmapped, ritchie, transfer,
# Nearest to mathematics: aquino, belatedly, avar, foundations, generalizes, generalization, algebraic, flatwater,
# Nearest to bbc: links, observances, jimmu, essentialism, subs, personalized, landen, friday,
# Nearest to consists: dera, myrtle, tagalog, probed, wali, savanna, appoints, consisting,
# Nearest to derived: everyday, virial, iehouah, veterinarian, greek, suffixes, trichomes, een,
# Nearest to operating: interface, powerbook, autocode, ide, going, intellimouse, scoreless, tramway,
# Nearest to heavy: electrically, dwindling, slugged, minimi, propellants, tribesmen, lollapalooza, pigmentation,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9954 0.3015 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9460 0.2981 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0197 0.2970 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0320 0.2981 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0298 0.2977 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9887 0.2983 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8908 0.2977 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9877 0.2973 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9700 0.3023 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9567 0.3050 sec/batch
# Nearest to will: emitter, wanted, natively, opted, bidi, sum, gluons, sniffing,
# Nearest to known: monocotyledons, artists, grenville, mauricien, stale, axioms, number, inaccurately,
# Nearest to zero: two, one, six, eight, five, four, seven, three,
# Nearest to only: this, pythons, michiel, chaerea, nda, again, luck, nlds,
# Nearest to state: united, lancaster, states, danville, subspace, montana, wisconsin, busan,
# Nearest to be: case, directionally, implies, stocking, venera, vagueness, absorbance, dysfunctions,
# Nearest to about: bauhin, external, quatrain, rework, fact, garifuna, uranus, moran,
# Nearest to may: lucid, memetic, infective, alaskan, to, complicated, either, iehovah,
# Nearest to running: congestion, mci, bahr, shuttlecock, ippolito, tcl, intercity, canola,
# Nearest to versions: compatibles, programmers, gui, wirth, ritchie, bitmapped, interpreter, scripts,
# Nearest to mathematics: aquino, belatedly, foundations, avar, generalizes, flatwater, generalization, algebraic,
# Nearest to bbc: links, observances, jimmu, subs, essentialism, transceiver, personalized, friday,
# Nearest to consists: dera, myrtle, tagalog, consisting, wali, probed, savanna, appoints,
# Nearest to derived: everyday, virial, trichomes, iehouah, greek, suffixes, veterinarian, abolitionism,
# Nearest to operating: interface, autocode, powerbook, ide, intellimouse, going, scoreless, mixture,
# Nearest to heavy: slugged, electrically, dwindling, minimi, tribesmen, lollapalooza, propellants, coolness,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0120 0.3017 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0200 0.3064 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9723 0.2970 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9847 0.2975 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0320 0.2985 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9268 0.2987 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9840 0.2974 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0030 0.2972 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9580 0.2979 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9865 0.2971 sec/batch
# Nearest to will: wanted, emitter, opted, must, natively, keep, bidi, sum,
# Nearest to known: monocotyledons, axioms, mauricien, grenville, examine, number, artists, stale,
# Nearest to zero: two, one, six, eight, five, seven, three, four,
# Nearest to only: this, michiel, pythons, nda, chaerea, just, since, eis,
# Nearest to state: united, lancaster, subspace, danville, states, vanish, medium, peotone,
# Nearest to be: case, implies, directionally, venera, vagueness, stocking, biases, monotheist,
# Nearest to about: external, quatrain, bauhin, rework, fact, moran, guardian, moncton,
# Nearest to may: lucid, memetic, to, infective, alaskan, either, iehovah, peerages,
# Nearest to running: congestion, bahr, shuttlecock, ippolito, tcl, mci, intercity, canola,
# Nearest to versions: compatibles, programmers, gui, wirth, interpreter, ritchie, bitmapped, transfer,
# Nearest to mathematics: foundations, aquino, belatedly, avar, generalization, flatwater, generalizes, timaeus,
# Nearest to bbc: links, observances, jimmu, essentialism, subs, monday, transceiver, personalized,
# Nearest to consists: dera, tagalog, myrtle, probed, wali, appoints, consisting, goss,
# Nearest to derived: virial, everyday, iehouah, greek, trichomes, posteriori, suffixes, derives,
# Nearest to operating: intellimouse, interface, powerbook, autocode, ide, going, scoreless, filenames,
# Nearest to heavy: dwindling, slugged, electrically, minimi, propellants, lollapalooza, tribesmen, coolness,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0176 0.3024 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9979 0.2984 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9809 0.2974 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0014 0.2978 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0158 0.3004 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0004 0.3000 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9776 0.2977 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9564 0.3003 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9411 0.3001 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0288 0.2993 sec/batch
# Nearest to will: wanted, opted, emitter, natively, sum, ahead, trieste, must,
# Nearest to known: monocotyledons, axioms, examine, artists, mauricien, nomenclature, number, polynesia,
# Nearest to zero: two, one, six, eight, five, four, three, seven,
# Nearest to only: michiel, this, conjugacy, pythons, again, extra, since, nda,
# Nearest to state: united, lancaster, subspace, danville, states, vanish, citizenship, peotone,
# Nearest to be: case, implies, venera, vagueness, directionally, stocking, biases, andropov,
# Nearest to about: external, fact, quatrain, bauhin, rework, moran, uranus, moncton,
# Nearest to may: to, either, memetic, lucid, peerages, alaskan, complicated, such,
# Nearest to running: congestion, tcl, shuttlecock, testers, ippolito, bahr, mci, canola,
# Nearest to versions: compatibles, programmers, wirth, gui, glosses, ritchie, scripts, interjection,
# Nearest to mathematics: foundations, aquino, belatedly, avar, flatwater, timaeus, lle, universiteit,
# Nearest to bbc: links, observances, jimmu, essentialism, subs, friday, monday, personalized,
# Nearest to consists: dera, appoints, tagalog, probed, myrtle, consisting, wali, longest,
# ...
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 4.0080 0.1644 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9499 0.2982 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9555 0.2990 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9372 0.2999 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.9551 0.2972 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.9429 0.2978 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.9511 0.2979 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.9160 0.2973 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9659 0.2979 sec/batch
# Nearest to will: wanted, opted, must, ahead, natively, gluons, keep, emitter,
# Nearest to known: monocotyledons, grenville, axioms, artists, mauricien, stale, ae, inaccurately,
# Nearest to zero: two, one, six, five, eight, four, three, seven,
# Nearest to only: this, again, chaerea, luck, record, conjugacy, pythons, since,
# Nearest to state: united, lancaster, danville, subspace, montana, states, emigrant, citizenship,
# Nearest to be: case, implies, venera, directionally, stocking, vagueness, musaf, andropov,
# Nearest to about: fact, uranus, quatrain, external, bauhin, rework, garifuna, moncton,
# Nearest to may: lucid, memetic, alaskan, to, either, infective, such, complicated,
# Nearest to running: congestion, tcl, ippolito, bahr, batu, mci, shuttlecock, testers,
# Nearest to versions: compatibles, programmers, wirth, gui, bitmapped, glosses, interjection, transfer,
# Nearest to mathematics: foundations, belatedly, avar, biomedical, socialize, flatwater, universiteit, aquino,
# Nearest to bbc: observances, links, jimmu, friday, monday, essentialism, weekdays, subs,
# Nearest to consists: dera, companion, consisting, tagalog, myrtle, longest, probed, broken,
# Nearest to derived: everyday, iehouah, greek, een, virial, suffixes, trichomes, derives,
# Nearest to operating: going, autocode, intellimouse, interface, ide, powerbook, mixture, nephites,
# Nearest to heavy: slugged, dwindling, electrically, minimi, lollapalooza, coolness, tribesmen, propellants,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9331 0.3009 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9661 0.2989 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8769 0.2987 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.9023 0.2978 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8941 0.2971 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8622 0.2988 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.9409 0.3167 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.9363 0.2995 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.9378 0.2970 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.9268 0.2968 sec/batch
# Nearest to will: wanted, must, opted, keep, ahead, emitter, gluons, natively,
# Nearest to known: monocotyledons, axioms, grenville, mauricien, stale, snack, number, incalculable,
# Nearest to zero: two, one, eight, six, five, four, three, seven,
# Nearest to only: this, luck, since, asl, again, startup, chaerea, extra,
# Nearest to state: danville, montana, lancaster, united, subspace, states, pioneers, dorms,
# Nearest to be: case, implies, directionally, venera, stocking, vagueness, sliders, musaf,
# Nearest to about: fact, uranus, quatrain, external, rework, bauhin, moncton, moran,
# Nearest to may: lucid, to, such, memetic, either, a, alaskan, infective,
# Nearest to running: congestion, tcl, testers, shuttlecock, bahr, ippolito, mci, batu,
# Nearest to versions: compatibles, programmers, wirth, interjection, glosses, bitmapped, gui, maupassant,
# Nearest to mathematics: foundations, avar, universiteit, belatedly, biomedical, flatwater, aquino, socialize,
# Nearest to bbc: observances, links, weekdays, friday, essentialism, monday, jimmu, subs,
# Nearest to consists: dera, tagalog, myrtle, consisting, companion, republika, probed, wali,
# Nearest to derived: everyday, iehouah, virial, si, een, trichomes, greek, suffixes,
# Nearest to operating: intellimouse, ide, interface, autocode, going, powerbook, mixture, nephites,
# Nearest to heavy: slugged, dwindling, electrically, minimi, tribesmen, lollapalooza, coolness, propellants,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9875 0.3013 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.9548 0.2988 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9115 0.2964 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9278 0.2979 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9564 0.2976 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9853 0.2974 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9415 0.2963 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9273 0.2979 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9469 0.2975 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 4.0009 0.2969 sec/batch
# Nearest to will: wanted, must, keep, opted, ahead, sum, emitter, madison,
# Nearest to known: monocotyledons, axioms, grenville, examine, mauricien, artists, stale, incalculable,
# Nearest to zero: two, one, six, five, eight, seven, four, three,
# Nearest to only: luck, conjugacy, this, record, since, michiel, chaerea, pythons,
# Nearest to state: lancaster, danville, subspace, united, montana, vanish, dorms, anglophones,
# Nearest to be: case, implies, venera, directionally, stocking, musaf, monotheist, vagueness,
# Nearest to about: uranus, external, fact, quatrain, rework, bauhin, moran, apparent,
# Nearest to may: lucid, such, memetic, either, to, alaskan, a, complicated,
# Nearest to running: congestion, bahr, testers, tcl, batu, shuttlecock, ippolito, mci,
# Nearest to versions: compatibles, interjection, wirth, glosses, mislead, maupassant, bitmapped, programmers,
# Nearest to mathematics: foundations, avar, universiteit, timaeus, belatedly, flatwater, tierney, oahu,
# Nearest to bbc: observances, links, friday, essentialism, monday, jimmu, weekdays, subs,
# Nearest to consists: dera, companion, myrtle, goss, consisting, probed, longest, anguage,
# Nearest to derived: iehouah, everyday, si, virial, derives, suffixes, een, greek,
# Nearest to operating: intellimouse, ide, interface, autocode, going, powerbook, mixture, nephites,
# Nearest to heavy: slugged, dwindling, minimi, electrically, coolness, tribesmen, lollapalooza, carpathians,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9301 0.3030 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9234 0.2979 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9374 0.2978 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.9037 0.2984 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9252 0.2966 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9702 0.2987 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8954 0.2994 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 4.0145 0.2986 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 4.0226 0.2977 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9945 0.2973 sec/batch
# Nearest to will: wanted, opted, madison, keep, sum, tadpoles, natively, must,
# Nearest to known: grenville, monocotyledons, axioms, mauricien, examine, incalculable, artists, redactor,
# Nearest to zero: two, one, five, eight, six, four, three, seven,
# Nearest to only: conjugacy, chaerea, luck, again, michiel, record, since, nda,
# Nearest to state: montana, united, danville, lancaster, states, emigrant, capitol, anglophones,
# Nearest to be: case, venera, implies, stocking, musaf, andropov, sliders, directionally,
# Nearest to about: fact, external, uranus, rework, quatrain, garifuna, moran, sinha,
# Nearest to may: such, alaskan, either, lucid, to, peerages, memetic, printable,
# Nearest to running: congestion, bahr, testers, tcl, batu, shuttlecock, sandy, ippolito,
# Nearest to versions: compatibles, wirth, maupassant, interjection, glosses, bitmapped, programmers, mislead,
# Nearest to mathematics: foundations, avar, timaeus, belatedly, schottenheimer, universiteit, flatwater, mathematical,
# Nearest to bbc: observances, links, friday, monday, jimmu, essentialism, weekdays, goran,
# Nearest to consists: dera, myrtle, consisting, probed, longest, republika, appoints, goss,
# Nearest to derived: iehouah, everyday, derives, si, een, suffixes, virial, ille,
# Nearest to operating: intellimouse, ide, interface, going, autocode, mixture, powerbook, tramway,
# Nearest to heavy: slugged, dwindling, lollapalooza, minimi, electrically, tribesmen, coolness, carpathians,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.9527 0.3022 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.9317 0.2958 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9407 0.2987 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8161 0.2994 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9645 0.2979 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9431 0.2981 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.9405 0.2994 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9602 0.0780 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.9209 0.2975 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.9190 0.3003 sec/batch
# Nearest to will: wanted, opted, madison, tadpoles, anna, natively, ahead, keep,
# Nearest to known: monocotyledons, grenville, was, number, mauricien, axioms, examine, artists,
# Nearest to zero: two, one, five, six, eight, four, three, seven,
# Nearest to only: conjugacy, asl, this, since, chaerea, luck, again, record,
# Nearest to state: montana, united, danville, states, lancaster, osage, anglophones, vanish,
# Nearest to be: case, implies, venera, stocking, directionally, vagueness, nymphet, musaf,
# Nearest to about: fact, uranus, external, quatrain, rework, bauhin, aconcagua, sinha,
# Nearest to may: lucid, such, alaskan, either, memetic, to, infective, varies,
# Nearest to running: congestion, testers, tcl, shuttlecock, inconsistent, bahr, linemen, ippolito,
# Nearest to versions: compatibles, wirth, glosses, interjection, gui, maupassant, programmers, bitmapped,
# Nearest to mathematics: foundations, avar, timaeus, schottenheimer, mathematical, oahu, flatwater, belatedly,
# Nearest to bbc: observances, links, friday, essentialism, weekdays, jimmu, monday, skyteam,
# Nearest to consists: dera, myrtle, companion, longest, tagalog, consisting, goss, subdivisions,
# Nearest to derived: iehouah, everyday, derives, si, greek, een, suffixes, virial,
# Nearest to operating: intellimouse, ide, interface, autocode, going, mixture, powerbook, scoreless,
# Nearest to heavy: slugged, lollapalooza, dwindling, tribesmen, minimi, electrically, coolness, ambulances,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8985 0.3031 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.9412 0.2975 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8654 0.2992 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.9310 0.2997 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8717 36.2643 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.9068 0.3208 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8939 36.2816 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9602 0.3199 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8436 15.3467 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8544 0.3245 sec/batch
# Nearest to will: wanted, opted, ahead, keep, madison, must, natively, anna,
# Nearest to known: monocotyledons, grenville, redactor, mauricien, was, stale, examine, artists,
# Nearest to zero: two, one, five, six, eight, four, three, seven,
# Nearest to only: this, conjugacy, luck, asl, since, startup, chaerea, record,
# Nearest to state: montana, united, states, danville, wisconsin, anglophones, lancaster, dorms,
# Nearest to be: case, implies, stocking, venera, directionally, internationals, been, dysfunctions,
# Nearest to about: fact, quatrain, external, uranus, bauhin, moncton, itis, aconcagua,
# Nearest to may: lucid, such, either, alaskan, to, memetic, a, varies,
# Nearest to running: congestion, testers, tcl, bahr, shuttlecock, inconsistent, batu, linemen,
# Nearest to versions: compatibles, interjection, maupassant, wirth, glosses, amundsen, cel, bitmapped,
# Nearest to mathematics: foundations, avar, biomedical, universiteit, schottenheimer, mathematical, flatwater, belatedly,
# Nearest to bbc: observances, links, weekdays, essentialism, friday, jimmu, monday, skyteam,
# Nearest to consists: dera, myrtle, companion, consisting, tagalog, subdivisions, longest, republika,
# Nearest to derived: iehouah, everyday, derives, si, greek, nammu, een, bovinae,
# Nearest to operating: intellimouse, going, ide, interface, autocode, mixture, powerbook, ported,
# Nearest to heavy: slugged, lollapalooza, dwindling, tribesmen, minimi, coolness, electrically, yao,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8920 0.3228 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8375 0.3149 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8562 0.3150 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.9075 0.3144 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.9084 0.3155 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.9009 0.3129 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9606 0.3373 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8614 0.3225 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.9045 0.3214 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8891 0.3161 sec/batch
# Nearest to will: wanted, keep, opted, ahead, must, madison, wish, sum,
# Nearest to known: monocotyledons, was, grenville, axioms, mauricien, redactor, examine, incalculable,
# Nearest to zero: two, one, five, eight, six, four, three, seven,
# Nearest to only: this, asl, luck, conjugacy, record, since, again, startup,
# Nearest to state: danville, montana, states, dorms, united, subspace, lancaster, jacurutu,
# Nearest to be: case, implies, directionally, stocking, venera, been, vagueness, for,
# Nearest to about: fact, external, quatrain, uranus, rework, bauhin, itis, masterwork,
# Nearest to may: such, lucid, alaskan, either, memetic, to, a, infective,
# Nearest to running: testers, tcl, congestion, linemen, bahr, mascots, inconsistent, nominee,
# Nearest to versions: compatibles, interjection, glosses, wirth, maupassant, mislead, bitmapped, cel,
# Nearest to mathematics: foundations, avar, mathematical, biomedical, tierney, flatwater, belatedly, generalization,
# Nearest to bbc: observances, links, weekdays, essentialism, friday, monday, jimmu, pruning,
# Nearest to consists: dera, companion, myrtle, tagalog, longest, broken, of, subdivisions,
# Nearest to derived: iehouah, derives, si, everyday, greek, earlier, een, virial,
# Nearest to operating: intellimouse, going, ide, autocode, interface, mixture, tramway, tallest,
# Nearest to heavy: lollapalooza, slugged, dwindling, minimi, tribesmen, coolness, electrically, telling,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.9114 0.3225 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9215 0.3176 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b1d3869cd0d6> in <module>()
#      14         batches = get_batches(train_words, batch_size, window_size)
#      15         start = time.time()
# ---> 16         for x, y in batches:
#      17
#      18             feed = {inputs: x,
#
# <ipython-input-11-bbde76dd99ea> in get_batches(words, batch_size, window_size)
#      12         for ii in range(len(batch)):
#      13             batch_x = batch[ii]
# ---> 14             batch_y = get_target(batch, ii, window_size)
#      15             y.extend(batch_y)
#      16             x.extend([batch_x]*len(batch_y))
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: expected bytes, NoneType found
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-20-4eeca6a379f0> in <module>()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
# ----> 5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#       6     embed_mat = sess.run(embedding)
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1437       return
#    1438     sess.run(self.saver_def.restore_op_name,
# -> 1439              {self.saver_def.filename_tensor_name: save_path})
#    1440
#    1441   @staticmethod
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/anacruz/miniconda3/envs/W2V/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# SystemError: <built-in function TF_Run> returned a result with an error set

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a4718e25bc97> in <module>()
#       1 viz_words = 500
#       2 tsne = TSNE()
# ----> 3 embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])
#
# NameError: name 'embed_mat' is not defined

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
